# %% [markdown]
# <a href="https://colab.research.google.com/github/dacardonave/Modelado-y-Simulacion/blob/master/Oscilador_Chua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oscilador de Chua
#
# Este oscilador constituye un sistema no lineal
# caótico. En sistemas descritos por ecuaciones diferenciales
# autónomas puede aparecer caos si hay, al menos, tres
# ecuaciones acopladas y además existe un término no-lineal
# en las variables dependientes. Se selecciona el circuito de
# Chua para describir los fenómenos caóticos.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# parameters
alpha = 15.395
beta = 28
R = -1.143
C_2 = -0.714

def chua(u, t):
    x, y, z = u  
    # electrical response of the nonlinear resistor
    f_x = C_2*x + 0.5*(R-C_2)*(abs(x+1)-abs(x-1))
    dudt = [alpha*(y-x-f_x), x - y + z, -beta * y]
    return dudt

# time discretization
t_0 = 0
dt = 1e-3
t_final = 500
t = np.arange(t_0, t_final, dt)

# initial conditions
u0 = [-0.2,0.2,2]
# integrate ode system
sol = odeint(chua, u0, t)

# 3d-plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.plot(sol[:,0],sol[:,1],sol[:,2])

# %%
# parameters
alpha = 15.395
beta = 28
R = 0.5
C_2 = 10*10**-9

# time discretization
t_0 = 0
dt = 1e-3
t_final = 500
t = np.arange(t_0, t_final, dt)

# initial conditions
u0 = [-0.2,0.2,2]
# integrate ode system
sol = odeint(chua, u0, t)

# 3d-plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.plot(sol[:,0],sol[:,1],sol[:,2])
