# %% [markdown]
# <a href="https://colab.research.google.com/github/dacardonave/Modelado-y-Simulacion/blob/master/Bifurcaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bifurcaciones
# ### Modelado y Simulacion
# ##### Daniel Cardona Velasquez
# ##### Universidad Nacional De Colombia

# %% [markdown]
# Este cuaderno de python implementa la simulacion de el concepto de bifurcaciones de algunas funciones matematicas

# %%
# Ejemplo página 55  Strogatz
import numpy as np
import matplotlib.pyplot as plt

# CÃ¡lculos para el dibujo el grÃ¡fico auxiliar para visualizar los puntos fijos

r = 4
x = np.linspace(-3,3)
dx = r*x-x**3

# Dibuja el grÃ¡fico auxiliar x vs. \dot x

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
#ax.set_xticks([-2,-1,1,2])
#ax.set_yticks([-6,-4,-2,2,4,6])

plt.plot(x,dx)
plt.show()

# %%
from scipy.integrate import solve_ivp
# Ejemplo página 55  Strogatz

def dx(t, x, r ,b): return r*x-x**b

r,b = 4,3
x0 = np.linspace(-6,6,10)
tspan = [0, 1]
sol = solve_ivp(dx, tspan, x0,args=(r,b),\
                dense_output = True)

#print(sol.t)
#print(sol.y[0])
t = np.linspace(tspan[0],tspan[1],101)
x = sol.sol(t)
for i in range(x0.size):
  #plt.plot(sol.t,sol.y[i])
  plt.plot(t,x[i])

x0 = np.linspace(-2,2,10)
tspan = [0, -1]
sol = solve_ivp(dx, tspan, x0,args=(r,b),\
                dense_output = True)

#print(sol.t)
#print(sol.y[0])
t = np.linspace(tspan[0],tspan[1],101)
x = sol.sol(t)
for i in range(x0.size):
  #plt.plot(sol.t,sol.y[i])
  plt.plot(t,x[i])
plt.show()

# %%
from scipy.integrate import solve_ivp
import time
# Equation in exercise_2_2_1
def dx(t, x, r ,b): return r*x-x**b

r,b = 4,3
x0 = np.linspace(-6,6,10)
tspan = [0, 100]

r = np.linspace(-2,2,100)
tic = time.time()
for j in range(r.size):
    sol = solve_ivp(dx, tspan, x0,args=(r[j],b))

    #print(sol.t)
    #print(sol.y[0])
    t = sol.t
    x = sol.y
    for i in range(x0.size):
        #plt.plot(r[j],x[i,-1])
        plt.scatter(r[j],x[i,-1] , color='darkgreen', marker='.')
        #print(r[j],x[i,-1])

r,b = 4,3
x0 = np.linspace(-.1,.1,5)
tspan = [0, -100]

r = np.linspace(0.1,2,100)
tic = time.time()
for j in range(r.size):
    sol = solve_ivp(dx, tspan, x0,args=(r[j],b))

    #print(sol.t)
    #print(sol.y[0])
    t = sol.t
    x = sol.y
    for i in range(x0.size):
        #plt.plot(r[j],x[i,-1])
        plt.scatter(r[j],x[i,-1] , color='red', marker='.')
        #print(r[j],x[i,-1])


toc = time.time()
plt.show()
print(toc-tic)
# Out:
# 5.537920236587524

# %%
# Ejercicio 3.1.1. página 79  Strogatz
import numpy as np
import matplotlib.pyplot as plt

# CÃ¡lculos para el dibujo el grÃ¡fico auxiliar para visualizar los puntos fijos

r = -5
x = np.linspace(-8,8)
dx = 1+r*x+x**2

# Dibuja el grÃ¡fico auxiliar x vs. \dot x

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
#ax.set_xticks([-2,-1,1,2])
#ax.set_yticks([-6,-4,-2,2,4,6])

plt.plot(x,dx)
plt.show()

# %%
def dx2(t, x, r ,b): return 1+r*x+x**b

r,b = -4,2
x0 = np.linspace(-8,8,10)
tspan = [0, 100]
sol = solve_ivp(dx2, tspan, x0,args=(r,b),\
                dense_output = True)

#print(sol.t)
#print(sol.y[0])
t = np.linspace(tspan[0],tspan[1],101)
x = sol.sol(t)
for i in range(x0.size):
  #plt.plot(sol.t,sol.y[i])
  plt.plot(t,x[i])


x0 = np.linspace(-10,10,10)
tspan = [0, -100]
sol = solve_ivp(dx2, tspan, x0,args=(r,b),\
                dense_output = True)

#print(sol.t)
#print(sol.y[0])
t = np.linspace(tspan[0],tspan[1],101)
x = sol.sol(t)
for i in range(x0.size):
  #plt.plot(sol.t,sol.y[i])
  plt.plot(t,x[i])


plt.show()

# %%
from scipy.integrate import solve_ivp
import time
# Ejercicio 3.1.1. página 79  Strogatz
def dx2(t, x, r ,b): return 1+r*x+x**b

r,b = -4,2
x0 = np.linspace(-6,6,10)
tspan = [0, 100]

r = np.linspace(-2,2,100)
tic = time.time()
for j in range(r.size):
    sol = solve_ivp(dx2, tspan, x0,args=(r[j],b))

    #print(sol.t)
    #print(sol.y[0])
    t = sol.t
    x = sol.y
    for i in range(x0.size):
        #plt.plot(r[j],x[i,-1])
        plt.scatter(r[j],x[i,-1] , color='darkgreen', marker='.')
        #print(r[j],x[i,-1])

r,b = 4,2
x0 = np.linspace(-.1,.1,5)
tspan = [0, -100]

r = np.linspace(0.1,2,100)
tic = time.time()
for j in range(r.size):
    sol = solve_ivp(dx2, tspan, x0,args=(r[j],b))

    #print(sol.t)
    #print(sol.y[0])
    t = sol.t
    x = sol.y
    for i in range(x0.size):
        #plt.plot(r[j],x[i,-1])
        plt.scatter(r[j],x[i,-1] , color='red', marker='.')
        #print(r[j],x[i,-1])


toc = time.time()
plt.show()
print(toc-tic)
# Out:
# 6.007057189941406

# %%
# Ejercicio 3.1.2. página 79  Strogatz
import numpy as np
import matplotlib.pyplot as plt


# Calculos para el dibujo el grÃ¡fico auxiliar para visualizar los puntos fijos

r = 50
x = np.linspace(-8,8)
dx = r-np.cosh(x)

# Dibuja el grÃ¡fico auxiliar x vs. \dot x

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
#ax.set_xticks([-2,-1,1,2])
#ax.set_yticks([-6,-4,-2,2,4,6])

plt.plot(x,dx)
plt.show()
